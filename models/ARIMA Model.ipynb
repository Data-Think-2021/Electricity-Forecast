# %% [markdown]
# <a id='ARIMA'></a>
# ## 10. ARIMA (AutoRegressive Integrated Moving Average) Model

# %% [markdown]
# ### An ARIMA model is a class of statistical models for analyzing and forecasting time series data. It explicitly caters to a suite of standard structures in time series data, and as such provides a simple yet powerful method for making skillful time series forecasts.

# %%
import pandas as pd
import numpy as np
from pandas import datetime
from datetime import datetime, timedelta
import itertools
from tqdm import tqdm_notebook

# auto_arima package
from pmdarima.arima.utils import ndiffs
import pmdarima as pm

# data visualization
# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import rcParams  # Dynamic rc settings
import seaborn as sns

# statistics
# from statsmodels.distributions.empirical_distribution import ECDF

# statistics
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.graphics.gofplots import qqplot

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

# %%
# load the data
tal_uni = pd.read_csv("tal_uni.csv", parse_dates=True, index_col = 0)

# %% [markdown]
# ### 10.1 Stationarity check
# 1) look at the plot 2) descriptive statistics 3) statistical tests
#
# A quick and dirty check to see if your time series is non-stationary is to review summary statistics. You can split your time series into two (or more) partitions and compare the mean and variance of each group. If they differ and the difference is statistically significant, the time series is likely non-stationary.

# %%
plt.plot(tal_uni)

# %%
X = tal_uni.values
split = int(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=320.083276, mean2=327.407323
# variance1=6798.039141, variance2=7582.855291

# %%
tal_uni.hist()
plt.show()

# %% [markdown]
# the distribution of values does not look like a Gaussian, therefore the mean and variance values are less meaningful. A log transform can be used to flatten out exponential change back to a linear relationship. Below is the same histogram with a log transform of the time series.

# %%
# we see the more familiar Gaussian-like or Uniform-like distribution of values.
X = tal_uni.values.copy()

# %%
# we see the more familiar Gaussian-like or Uniform-like distribution of values.
X = tal_uni.values.copy()
X = np.log(X)
split = int(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
plt.hist(X)
plt.show()
plt.plot(X)
plt.show()
# Out:
# mean1=5.736737, mean2=5.757274
# variance1=0.062973, variance2=0.067068

# %% [markdown]
# ### The mean and variance are very close for this split. This suggest stationary time series. However we might expect the daily, monthly seasonality there. To verify our guess we need to implement robust statistical test.

# %% [markdown]
# ## Test 1: Kwiatkowski-Phillips-Schmidt-Shin (KPSS) test for stationarity
# The null hypothesis of KPSS test is that the series are stationary.

# %%
from statsmodels.tsa.stattools import kpss
X = tal_uni.values.flatten()
result = kpss(X)
print('KPSS Statistic: %f' % result[0]) 
print('p-value: %f' % result[1]) 
print('Critical Values:')
for key, value in result[3].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# KPSS Statistic: 2.061756
# p-value: 0.010000
# Critical Values:
# 	10%: 0.347
# 	5%: 0.463
# 	2.5%: 0.574
# 	1%: 0.739

# %% [markdown]
# ## The test statistic is much bigger than the 1% critical value, indicating that the null hypothesis is rejected. That is, the data are not stationary. We can difference the data, and apply the test again.

# %%
# stationarity test on the differenced data
# convert the differenced dataframe to 1d array using flatten()
X = tal_uni.diff().dropna().values.flatten()

result = kpss(X)
print('KPSS Statistic: %f' % result[0]) 
print('p-value: %f' % result[1]) 
print('Critical Values:')
for key, value in result[3].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# KPSS Statistic: 0.001987
# p-value: 0.100000
# Critical Values:
# 	10%: 0.347
# 	5%: 0.463
# 	2.5%: 0.574
# 	1%: 0.739

# %% [markdown]
# ### The p-value is 0.10 larger than the critical value 0.05. This time we cannot reject the hypthesis. We can conclude the differenced data are stationary.  That indicates the order of differencing to be d=1.

# %% [markdown]
# ## Test 2:  Augmented Dickey-Fuller (ADF) test
# ### The null hypothesis of the Augmented Dickey-Fuller is that there is a unit root, with the alternative that there is no unit root. If the pvalue is above a critical size, then we cannot reject that there is a unit root.

# %%
from statsmodels.tsa.stattools import adfuller
X = tal_uni.values.flatten()
result = adfuller(X)
print('ADF Statistic: %f' % result[0]) 
print('p-value: %f' % result[1]) 
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -10.309964
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# ### We got p-value equal to 0. This suggests that we can reject the null hypothesis with a significance level of less than 1% (i.e. a low probability that the result is a statistical fluke). Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure. We got a different result than KPSS test.

# %% [markdown]
# ## 10.2 Check the ACF/PACF plots

# %% [markdown]
# i) on the original data

# %%
# figure for subplots
plt.figure(figsize = (12, 8))
# acf and pacf for demand
plt.subplot(221); plot_acf(tal_uni, lags = 50, ax = plt.gca())
plt.subplot(222); plot_pacf(tal_uni, lags = 50, ax = plt.gca())

# %% [markdown]
# ### From ACF plot we saw recognized the cyclic pattern/ seasonality inside. From PACF we can say the order of AR term(p) should be equal to 3, which crosses the significant limit.

# %% [markdown]
# ii) on the differenced data

# %%
# figure for subplots
plt.figure(figsize = (12, 8))
# acf and pacf for demand
plt.subplot(221); plot_acf(tal_uni.diff(24).dropna(), lags = 50, ax = plt.gca())
plt.subplot(222); plot_pacf(tal_uni.diff(24).dropna(), lags = 50, ax = plt.gca())

# %% [markdown]
# The ACF in the first image clearly shows an daily seasonal trend. Peaks every 24 hours lag at about 24, etc.
# Since, we observe daily seasonality

# %% [markdown]
# ## 10.3 SARIMA Model

# %% [markdown]
# First, we fit an ARIMA(3,1,0) model. This sets the lag value to 3 for autoregression, uses a difference order of 1 to make the time series stationary, and uses a moving average model of 0.

# %%
y = tal_uni.values

## Adf Test
#ndiffs(y, test='adf')  # 0

# KPSS test
#ndiffs(y, test='kpss')  # 1

# PP test:
ndiffs(y, test='pp')  # 0
# Out:
# 0

# %%
def optimizeSARIMA(parameters_list, d, D, s):
    
    results = []
    best_aic = float("inf")

    for param in tqdm_notebook(parameters_list):
        # we need try-except because on some combinations model fails to converge
        try:
            model=sm.tsa.statespace.SARIMAX(train.demand, order=(param[0], d, param[1]), 
                                            seasonal_order=(param[2], D, param[3], s)).fit(disp=-1)
        except:
            continue
        aic = model.aic
        # saving best model, AIC and parameters
        if aic < best_aic:
            best_model = model
            best_aic = aic
            best_param = param
        results.append([param, model.aic])

    result_table = pd.DataFrame(results)
    result_table.columns = ['parameters', 'aic']
    # sorting in ascending order, the lower AIC is - the better
    result_table = result_table.sort_values(by='aic', ascending=True).reset_index(drop=True)
    
    return result_table

# %%
import pmdarima as pm

# Seasonal - fit stepwise auto-ARIMA
smodel = pm.auto_arima(tal_uni.iloc[-1000:], start_p=1, start_q=1,
                         #test='adf',
                         max_p=4, max_q=3, m=24,
                         start_P=0, 
                         seasonal=True,
                         d=1, 
                         D=1, 
                         trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

smodel.summary()
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 24); AIC=6934.755, BIC=6959.167, Fit time=16.698 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 24); AIC=7367.655, BIC=7377.419, Fit time=0.427 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 24); AIC=7173.534, BIC=7193.064, Fit time=10.220 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 24); AIC=6957.128, BIC=6976.658, Fit time=11.525 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 24); AIC=6915.175, BIC=6944.470, Fit time=26.228 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 0, 24); AIC=7175.325, BIC=7199.737, Fit time=16.249 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 24); AIC=6916.464, BIC=6950.641, Fit time=71.088 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 24); AIC=7314.472, BIC=7334.002, Fit time=1.904 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 2, 24); AIC=6885.782, BIC=6924.841, Fit time=102.386 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 1, 2, 24); AIC=6905.040, BIC=6939.217, Fit time=84.227 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 1, 2, 24); AIC=6875.360, BIC=6919.302, Fit time=138.493 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(2, 1, 2, 24); AIC=6883.359, BIC=6922.419, Fit time=112.920 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 1, 2, 24); AIC=6863.398, BIC=6912.223, Fit time=168.762 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 2, 24); AIC=6894.453, BIC=6938.395, Fit time=132.755 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 1, 1, 24); AIC=6892.488, BIC=6936.430, Fit time=138.499 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 1, 24); AIC=6893.419, BIC=6932.478, Fit time=44.228 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 2, 24); AIC=6862.868, BIC=6906.810, Fit time=122.737 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 24); AIC=6893.640, BIC=6932.699, Fit time=81.204 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 1, 24); AIC=6891.746, BIC=6930.805, Fit time=85.559 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 24); AIC=6892.565, BIC=6926.742, Fit time=25.978 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(2, 1, 2, 24); AIC=6862.628, BIC=6901.687, Fit time=94.510 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 2, 24); AIC=6893.698, BIC=6927.875, Fit time=64.677 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(2, 1, 1, 24); AIC=6891.886, BIC=6926.063, Fit time=55.739 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 1, 24); AIC=6892.556, BIC=6921.851, Fit time=19.620 seconds
# Total fit time: 1626.809 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                 1000
# Model:             SARIMAX(0, 1, 2)x(2, 1, 2, 24)   Log Likelihood               -3423.314
# Date:                            Tue, 03 Dec 2019   AIC                           6862.628
# Time:                                    23:10:27   BIC                           6901.687
# Sample:                                         0   HQIC                          6877.491
#                                            - 1000
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -4.596e-05      0.030     -0.002      0.999      -0.058       0.058
# ma.L1          0.3012      0.024     12.739      0.000       0.255       0.348
# ma.L2          0.2278      0.025      9.091      0.000       0.179       0.277
# ar.S.L24       0.8455      0.084     10.072      0.000       0.681       1.010
# ar.S.L48      -0.2942      0.033     -8.891      0.000      -0.359      -0.229
# ma.S.L24      -1.6030      0.085    -18.811      0.000      -1.770      -1.436
# ma.S.L48       0.6697      0.079      8.490      0.000       0.515       0.824
# sigma2        62.8548      2.046     30.725      0.000      58.845      66.864
# ===================================================================================
# Ljung-Box (Q):                       63.55   Jarque-Bera (JB):               378.98
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.96   Skew:                            -0.52
# Prob(H) (two-sided):                  0.75   Kurtosis:                         5.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# fit model
model = SARIMAX(train, order=(0,1,2), seasonal_order=(2,1,2,24))
model_fit = model.fit(disp=0)
# summary of fit model 
print(model_fit.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             demand   No. Observations:                  976
# Model:             SARIMAX(0, 1, 2)x(2, 1, 2, 24)   Log Likelihood               -3328.329
# Date:                            Tue, 03 Dec 2019   AIC                           6670.658
# Time:                                    23:55:52   BIC                           6704.660
# Sample:                                09-04-2019   HQIC                          6683.612
#                                      - 10-15-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.3025      0.025     11.897      0.000       0.253       0.352
# ma.L2          0.2172      0.026      8.320      0.000       0.166       0.268
# ar.S.L24      -0.3579      2.272     -0.158      0.875      -4.811       4.096
# ar.S.L48       0.1144      0.420      0.272      0.785      -0.709       0.938
# ma.S.L24      -0.4182      2.277     -0.184      0.854      -4.881       4.045
# ma.S.L48      -0.5305      2.195     -0.242      0.809      -4.832       3.771
# sigma2        60.5830      2.045     29.627      0.000      56.575      64.591
# ===================================================================================
# Ljung-Box (Q):                       66.01   Jarque-Bera (JB):               514.95
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.83   Skew:                            -0.61
# Prob(H) (two-sided):                  0.10   Kurtosis:                         6.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
# Forecast
yhat = model_fit.forecast(24)  # 95% conf 

# Make as pandas series
fc_series = pd.Series(yhat, index=test.iloc[:24].index)
#lower_series = pd.Series(conf[:, 0], index=test.index)
#upper_series = pd.Series(conf[:, 1], index=test.index)

rmse_sarima = np.sqrt(mean_squared_error(test.iloc[:24],fc_series))
rmse_sarima

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train.iloc[-24:], label='training')
plt.plot(test.iloc[:24], label='actual')
plt.plot(fc_series , label='forecast')
#plt.fill_between(lower_series.index, lower_series, upper_series, 
 #                color='k', alpha=.15)
plt.title('SARIMA 24 steps forecast')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
# Forecast
model_fit_1 = smodel.fit(y = )
#yhat_1 = smodel.forecast(24)  # 95% conf
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-431cc0a8696e> in <module>
#       1 # Forecast
# ----> 2 model_fit_1 = smodel.fit(disp=0)
#       3 #yhat_1 = smodel.forecast(24)  # 95% conf
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %% [markdown]
# The Akaike information criterion (AIC) is an estimator of the relative quality of statistical models for a given set of data. Given a collection of models for the data, AIC estimates the quality of each model, relative to each of the other models.
# The AIC value will allow us to compare how well a model fits the data and takes into account the complexity of a model, so models that have a better fit while using fewer features will receive a better (lower) AIC score than similar models that utilize more features.

# %%
n_test = 1 * 24 # test only on 24 hours 
train, test = tal_uni.iloc[-1000:-n_test], tal_uni.iloc[-n_test:]

# %%
# fit model
model = SARIMAX(train, order=(3,1,2), seasonal_order=(2,1,2,24))
model_fit = model.fit(disp=0)
# summary of fit model 
print(model_fit.summary())

# %%
# fit model
model = SARIMAX(train, order=(3,1,2), seasonal_order=(2,1,2,24))
model_fit = model.fit(disp=0)
# summary of fit model 
print(model_fit.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             demand   No. Observations:                  976
# Model:             SARIMAX(3, 1, 2)x(2, 1, 2, 24)   Log Likelihood               -3315.308
# Date:                            Tue, 03 Dec 2019   AIC                           6650.616
# Time:                                    23:19:10   BIC                           6699.191
# Sample:                                09-04-2019   HQIC                          6669.123
#                                      - 10-15-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7348      0.161      4.572      0.000       0.420       1.050
# ar.L2          0.2981      0.190      1.568      0.117      -0.074       0.671
# ar.L3         -0.2726      0.049     -5.592      0.000      -0.368      -0.177
# ma.L1         -0.4847      0.164     -2.962      0.003      -0.806      -0.164
# ma.L2         -0.3473      0.159     -2.182      0.029      -0.659      -0.035
# ar.S.L24      -0.1181     32.313     -0.004      0.997     -63.451      63.215
# ar.S.L48       0.0564      6.075      0.009      0.993     -11.851      11.964
# ma.S.L24      -0.6563     32.309     -0.020      0.984     -63.981      62.668
# ma.S.L48      -0.2942     31.094     -0.009      0.992     -61.237      60.649
# sigma2        59.0569      1.996     29.586      0.000      55.145      62.969
# ===================================================================================
# Ljung-Box (Q):                       60.37   Jarque-Bera (JB):               524.45
# Prob(Q):                              0.02   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                            -0.62
# Prob(H) (two-sided):                  0.11   Kurtosis:                         6.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# fit model
model = SARIMAX(train, order=(3,1,1), seasonal_order=(2,1,1,24))
model_fit = model.fit(disp=0)
# summary of fit model 
print(model_fit.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             demand   No. Observations:                  976
# Model:             SARIMAX(3, 1, 1)x(2, 1, 1, 24)   Log Likelihood               -3320.276
# Date:                            Tue, 03 Dec 2019   AIC                           6656.552
# Time:                                    22:40:20   BIC                           6695.412
# Sample:                                09-04-2019   HQIC                          6671.357
#                                      - 10-15-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5597      0.152      3.674      0.000       0.261       0.858
# ar.L2          0.0169      0.054      0.315      0.753      -0.088       0.122
# ar.L3         -0.1964      0.028     -6.906      0.000      -0.252      -0.141
# ma.L1         -0.2939      0.153     -1.920      0.055      -0.594       0.006
# ar.S.L24       0.1947      0.034      5.721      0.000       0.128       0.261
# ar.S.L48      -0.0418      0.037     -1.139      0.255      -0.114       0.030
# ma.S.L24      -0.9454      0.023    -41.743      0.000      -0.990      -0.901
# sigma2        60.0523      2.054     29.231      0.000      56.026      64.079
# ===================================================================================
# Ljung-Box (Q):                       74.35   Jarque-Bera (JB):               397.30
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.85   Skew:                            -0.58
# Prob(H) (two-sided):                  0.16   Kurtosis:                         5.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### From the table above, the P Values of the AR1, AR2, MAL1,ar.s.L12, ar.S.L24,ma.S.l12 terms are highly significant (<< 0.05).

# %%
# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(test):
    # prepare training dataset
   # n_test = int(1*24*1)   # set the test size 
    #train, test = X[0:-n_test], X[-n_test:]
    #history = [x for x in train]
    # make predictions
    predictions = list()
    for t in range(len(test)):
       # model = SARIMAX(history, order=(2,1,1), seasonal_order=(2,1,1,12))   #ARIMA(2,1,1)(2,1,1)12
        #model_fit = model.fit(disp=0)
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        #history.append(test[t])
    # calculate out of sample error
    rmse = np.sqrt(mean_squared_error(test, predictions))
    print('RMSE: %f'% rmse)
    return rmse

# %%
#X = tal_uni.values
evaluate_arima_model(test)
# Out:
# RMSE: 96.287490
# 96.28749028902553

# %%
model_fit.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
# Forecast
yhat = model_fit.forecast(24)  # 95% conf

# %%
# Make as pandas series
fc_series = pd.Series(yhat, index=test.iloc[:24].index)
#lower_series = pd.Series(conf[:, 0], index=test.index)
#upper_series = pd.Series(conf[:, 1], index=test.index)

rmse_sarima = np.sqrt(mean_squared_error(test.iloc[:24],fc_series))
rmse_sarima
# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train.iloc[-24:], label='training')
plt.plot(test.iloc[:24], label='actual')
plt.plot(fc_series , label='forecast')
#plt.fill_between(lower_series.index, lower_series, upper_series, 
 #                color='k', alpha=.15)
plt.title('SARIMA 24 steps forecast')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
# line plot of residuals
residuals_arima = pd.DataFrame(model_fit.resid) 
residuals_arima.plot()
plt.show()

# %%
# figure for subplots
plt.figure(figsize = (12, 8))
# acf and pacf for demand
plt.subplot(221); plot_acf(residuals_arima, lags = 50, ax = plt.gca())
plt.subplot(222); plot_pacf(residuals_arima, lags = 50, ax = plt.gca())

# %%
model1 = ARIMA(train, order=(2,1,0))
model_fit1 = model1.fit(disp = 0)
yhat =model_fit1.predict(start=len(train), end=len(train)+23, typ='levels')
yhat

#rmse = np.sqrt(mean_squared_error(test_A, yhat))
# Out:
# 2019-10-15 04:00:00    247.041356
# 2019-10-15 05:00:00    238.559686
# 2019-10-15 06:00:00    231.319639
# 2019-10-15 07:00:00    225.137047
# 2019-10-15 08:00:00    219.855992
# 2019-10-15 09:00:00    215.343608
# 2019-10-15 10:00:00    211.486612
# 2019-10-15 11:00:00    208.188420
# 2019-10-15 12:00:00    205.366680
# 2019-10-15 13:00:00    202.951175
# 2019-10-15 14:00:00    200.882038
# 2019-10-15 15:00:00    199.108224
# 2019-10-15 16:00:00    197.586211
# 2019-10-15 17:00:00    196.278890
# 2019-10-15 18:00:00    195.154623
# 2019-10-15 19:00:00    194.186431
# 2019-10-15 20:00:00    193.351313
# 2019-10-15 21:00:00    192.629659
# 2019-10-15 22:00:00    192.004747
# 2019-10-15 23:00:00    191.462320
# 2019-10-16 00:00:00    190.990222
# 2019-10-16 01:00:00    190.578088
# 2019-10-16 02:00:00    190.217082
# 2019-10-16 03:00:00    189.899668
# Freq: H, dtype: float64

# %%
# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

# %%
forecast
# Out:
# array([0.49764752, 0.72879335, 0.8100434 , 0.80956817, 0.76690855,
#        0.70472279, 0.63574849, 0.56692424, 0.50182573, 0.44210225,
#        0.3883207 , 0.34045891, 0.29819163, 0.26105432, 0.22853512,
#        0.20012488, 0.17534281, 0.15374827, 0.13494472, 0.11857941,
#        0.1043409 , 0.09195559, 0.08118395, 0.07181673])

# %%
# seasonal difference
X = tal_uni.values
hours_of_day = 24
differenced = tal_uni.diff(24).dropna().values
# fit model
model = ARIMA(differenced, order=(2,0,1))
model_fit = model.fit(disp=0)
# multi-step out-of-sample forecast
start_index = len(differenced)
end_index = start_index + 23
forecast = model_fit.predict(start=start_index, end=end_index)
# invert the differenced forecast to something usable
history = [x for x in X]
hour = 1
for yhat in forecast:
	inverted = inverse_difference(history, yhat, hours_of_day)
	print('hour %d: %f' % (hour, inverted))
	history.append(inverted)
	hour += 1
# Out:
# hour 1: 250.497648
# hour 2: 249.728793
# hour 3: 262.810043
# hour 4: 297.809568
# hour 5: 339.766909
# hour 6: 342.704723
# hour 7: 337.635748
# hour 8: 344.566924
# hour 9: 358.501826
# hour 10: 358.442102
# hour 11: 363.388321
# hour 12: 374.340459
# hour 13: 387.298192
# hour 14: 362.261054
# hour 15: 378.228535
# hour 16: 377.200125
# hour 17: 392.175343
# hour 18: 388.153748
# hour 19: 363.134945
# hour 20: 337.118579
# hour 21: 314.104341
# hour 22: 288.091956
# hour 23: 269.081184
# hour 24: 257.071817

# %%
len(history)
# Out:
# 37659

# %%
len(X)
# Out:
# 37635
